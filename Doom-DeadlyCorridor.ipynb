# %%
# Import vizdoom for game env
from vizdoom import *
# Import radom action for sampling random actions
import random
# Import time for sleep
import time
# Import numpy for identity matrix
import numpy as np
# Import environment base class from OpenAI gym
from gym import Env
# Import gym spaces for defining the action space, Box returns a n-dim array, Discrete is a set of binary values
from gym.spaces import Discrete, Box
# Import opencv for image processing (grayscaling)
import cv2
# Import matplotlib 
from matplotlib import pyplot as plt

# %%
# Setup the game
game = DoomGame()
game.load_config('ViZDoom/gtihub/ViZDoom/scenarios/deadly_corridor_s1.cfg')
game.init()

# %%
actions = np.identity(7, dtype=np.uint8)

# %%
# loop through the episodes
episodes = 10
for episode in range(episodes):
    game.new_episode()
    while not game.is_episode_finished():
        state = game.get_state()
        img = state.screen_buffer
        info = state.game_variables        
        reward = game.make_action(random.choice(actions),4)
        print('reward', reward)
        time.sleep(0.02)
    print('Result', game.get_total_reward())
    time.sleep(2)

# %%
game.close()

# %%
class VizDoomEnv(Env):
    # function that is called when we start env
    def __init__(self, render = False, config='ViZDoom/gtihub/ViZDoom/scenarios/deadly_corridor.cfg'):
        # Inherit from Env
        super().__init__()
        
        self.game = DoomGame()
        self.game.load_config(config)

        self.observation_space = Box(low =0, high = 255, shape = (100, 160, 1), dtype = np.uint8)
        self.action_space = Discrete(7)

        # game variables : HEALTH DAMAGE_TAKEN HITCOUNT SELECTED_WEAPON_AMMO
        self.damage_taken = 0
        self.hitcount = 0
        self.ammo = 52

        # render frame logic
        if render == False:
            self.game.set_window_visible(False)
        else:
            self.game.set_window_visible(True)

        # start the game
        self.game.init()

        
    # this is how we take a step in the environment    
    def step(self, action):
        # actions = array([[1, 0, 0],
        ##                 [0, 1, 0],
        ##                 [0, 0, 1]], dtype=uint8)
        
        actions = np.identity(7, dtype = np.uint8)

        # take an action with a frameskip of 4 - frameskip is needed for AI to get feedback
        movement_reward = self.game.make_action(actions[action], 4)

        reward = 0
        if self.game.get_state():
            # get the screen image and game variables
            state = self.game.get_state().screen_buffer
            state = self.grayscale(state)

            ##### perform reward shaping ####
            game_variables = self.game.get_state().game_variables
            health, damage_taken, hitcount, ammo = game_variables

            # calculate deltas, damage starts with past 10, current frame = 20 delta = -20 + 10 (disint
            damage_taken_delta = self.damage_taken - damage_taken
            self.damage_taken = damage_taken
            hitcount_delta = - self.hitcount + hitcount
            self.hitcount = hitcount
            ammo_delta = - self.ammo + ammo
            self.ammo = ammo

            reward = movement_reward + damage_taken_delta*10 + hitcount_delta*200 + ammo_delta*5
            info = ammo
        # handling game end scenario when get_state and ammo are zeros
        else:
            state = np.zeros(self.observation_space.shape)
            info = 0

        info = {"info":info}
        done = self.game.is_episode_finished()
        return state, reward, done, info

    # reset the instance 
    def reset(self):
        self.game.new_episode()
        state = self.game.get_state().screen_buffer            

        # game variables : HEALTH DAMAGE_TAKEN HITCOUNT SELECTED_WEAPON_AMMO
        self.damage_taken = 0
        self.hitcount = 0
        self.ammo = 52
        
        return self.grayscale(state)
        
 
    # grayscale the game frame and resize it 
    ## observation will be the gameframe
    def grayscale(self, observation):
        ## moveaxis will rearange the order in a way that cvtColor can accept
        ### in this instance from (3, 240, 320) to (240, 320, 3) - color channels at the end
        gray = cv2.cvtColor(np.moveaxis(observation, 0, -1), cv2.COLOR_BGR2GRAY)

        ##cut the frame down to scale down and reduces the pixels
        resize = cv2.resize(gray, (160, 100), interpolation = cv2.INTER_CUBIC)
        state = np.reshape(resize, (100, 160, 1))
        return state
        
   # this is already defined to render but vizdoom does this for us
    def render():
        pass 
        
    def close(self):
        self.game.close()

# %%
env = VizDoomEnv(render = True)

# %%
env.close()

# %%
# Import Environment checker
from stable_baselines3.common import env_checker

# %%
env_checker.check_env(env)

# %% [markdown]
# # 3. View State

# %%
plt.imshow(cv2.cvtColor(state, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # 4. Set up CallBack

# %%
# Import os for file navigation
import os
# Import callback class from sb3
from stable_baselines3.common.callbacks import BaseCallback

# %%
class TrainingLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainingLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/train_deadly_corridor'
LOG_DIR = './logs/log_deadly_corridor'

# %%
# Setup the call back
callback = TrainingLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR)

# %% [markdown]
# # 5 Train Model using Curriculum

# %%
# Import PPO (Proximal Policy Optimization) for algorithm 
from stable_baselines3 import PPO

# %%
# Non rendered environment
env = VizDoomEnv(config='ViZDoom/gtihub/ViZDoom/scenarios/deadly_corridor_s1.cfg')

# %%
#n_steps = how many time_frames that are passed as a part of initial run - larger the value more info is passed and longer to learn
model = PPO('CnnPolicy', env, tensorboard_log = LOG_DIR, verbose = 1, learning_rate = 0.00001, n_steps = 8192, clip_range=.1, gamma=.95, gae_lambda = .9)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
#model = PPO.load('./train/train_basic/best_model_100000', tensorboard_log=LOG_DIR)
#model.set_env(env)
#model.learning_rate = 0.0000001

# %%
model.learn(total_timesteps = 400000, callback = callback)
# Out:
# Logging to ./logs/log_deadly_corridor\PPO_2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 205      |
# |    ep_rew_mean     | -561     |
# | time/              |          |
# |    fps             | 26       |
# |    iterations      | 1        |
# |    time_elapsed    | 311      |
# |    total_timesteps | 8192     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 209          |
# |    ep_rew_mean          | -542         |
# | time/                   |              |
# |    fps                  | 19           |
# |    iterations           | 2            |
# |    time_elapsed         | 826          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0028062842 |
# |    clip_fraction        | 0.129        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 4.18e-05     |
# |    learning_rate        | 1e-05        |
# |    loss                 | 1.86e+03     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00365     |
# |    value_loss           | 3.48e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 178          |
# |    ep_rew_mean          | -544         |
# | time/                   |              |
# |    fps                  | 18           |
# |    iterations           | 3            |
# |    time_elapsed         | 1344         |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0028120931 |
# |    clip_fraction        | 0.166        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.0051       |
# |    learning_rate        | 1e-05        |
# |    loss                 | 1.25e+03     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00511     |
# |    value_loss           | 3.72e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 122         |
# |    ep_rew_mean          | -544        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 4           |
# |    time_elapsed         | 1857        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.002654208 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | 0.0157      |
# |    learning_rate        | 1e-05       |
# |    loss                 | 2.86e+03    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00354    |
# |    value_loss           | 4.74e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 115          |
# |    ep_rew_mean          | -513         |
# | time/                   |              |
# |    fps                  | 17           |
# |    iterations           | 5            |
# |    time_elapsed         | 2375         |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0034626874 |
# |    clip_fraction        | 0.178        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.92        |
# |    explained_variance   | 0.0481       |
# |    learning_rate        | 1e-05        |
# |    loss                 | 2.99e+03     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00442     |
# |    value_loss           | 5.95e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 101          |
# |    ep_rew_mean          | -491         |
# | time/                   |              |
# |    fps                  | 17           |
# |    iterations           | 6            |
# |    time_elapsed         | 2881         |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0030042073 |
# |    clip_fraction        | 0.196        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.9         |
# |    explained_variance   | 0.0853       |
# |    learning_rate        | 1e-05        |
# |    loss                 | 2.34e+03     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00353     |
# |    value_loss           | 6e+03        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 103          |
# |    ep_rew_mean          | -434         |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 7            |
# |    time_elapsed         | 3399         |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0032878986 |
# |    clip_fraction        | 0.195        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.89        |
# |    explained_variance   | 0.111        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 2.18e+03     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00478     |
# |    value_loss           | 6.58e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 98.6         |
# |    ep_rew_mean          | -421         |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 8            |
# |    time_elapsed         | 3909         |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0030233827 |
# |    clip_fraction        | 0.185        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.87        |
# |    explained_variance   | 0.133        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 2.8e+03      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00329     |
# |    value_loss           | 6.14e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 94.3         |
# |    ep_rew_mean          | -430         |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 9            |
# |    time_elapsed         | 4423         |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0029306936 |
# |    clip_fraction        | 0.194        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.88        |
# |    explained_variance   | 0.139        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 4.24e+03     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00215     |
# |    value_loss           | 7.26e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 89.8         |
# |    ep_rew_mean          | -359         |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 10           |
# |    time_elapsed         | 4938         |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0025681192 |
# |    clip_fraction        | 0.186        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.85        |
# |    explained_variance   | 0.172        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 2.76e+03     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00242     |
# |    value_loss           | 6.66e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 82.9         |
# |    ep_rew_mean          | -342         |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 11           |
# |    time_elapsed         | 5460         |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0030765506 |
# |    clip_fraction        | 0.225        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.83        |
# |    explained_variance   | 0.171        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 3.34e+03     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00386     |
# |    value_loss           | 7.82e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 77.8         |
# |    ep_rew_mean          | -304         |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 12           |
# |    time_elapsed         | 5989         |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0033710739 |
# |    clip_fraction        | 0.223        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.79        |
# |    explained_variance   | 0.132        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 3.26e+03     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00231     |
# |    value_loss           | 8.47e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.7        |
# |    ep_rew_mean          | -273        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 13          |
# |    time_elapsed         | 6493        |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.002820347 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.76       |
# |    explained_variance   | 0.147       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 4.71e+03    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00121    |
# |    value_loss           | 7.95e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 70.5        |
# |    ep_rew_mean          | -258        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 14          |
# |    time_elapsed         | 7000        |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.002977422 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | 0.173       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 4.11e+03    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00111    |
# |    value_loss           | 7.54e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 77.2       |
# |    ep_rew_mean          | -165       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 15         |
# |    time_elapsed         | 7504       |
# |    total_timesteps      | 122880     |
# | train/                  |            |
# |    approx_kl            | 0.00322882 |
# |    clip_fraction        | 0.243      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -1.67      |
# |    explained_variance   | 0.203      |
# |    learning_rate        | 1e-05      |
# |    loss                 | 4.08e+03   |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.00249   |
# |    value_loss           | 8.64e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 64.5         |
# |    ep_rew_mean          | -193         |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 16           |
# |    time_elapsed         | 8012         |
# |    total_timesteps      | 131072       |
# | train/                  |              |
# |    approx_kl            | 0.0035117867 |
# |    clip_fraction        | 0.222        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.63        |
# |    explained_variance   | 0.199        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 3.11e+03     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00254     |
# |    value_loss           | 8.69e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 66.9        |
# |    ep_rew_mean          | -223        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 17          |
# |    time_elapsed         | 8516        |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.004549294 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | 0.207       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 5.84e+03    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00226    |
# |    value_loss           | 9.52e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61.5        |
# |    ep_rew_mean          | -204        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 18          |
# |    time_elapsed         | 9028        |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.003207833 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | 0.255       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 3.56e+03    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0016     |
# |    value_loss           | 8.67e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 53.4         |
# |    ep_rew_mean          | -222         |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 19           |
# |    time_elapsed         | 9537         |
# |    total_timesteps      | 155648       |
# | train/                  |              |
# |    approx_kl            | 0.0041749626 |
# |    clip_fraction        | 0.244        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | 0.24         |
# |    learning_rate        | 1e-05        |
# |    loss                 | 4.1e+03      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00167     |
# |    value_loss           | 1.05e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 57.1         |
# |    ep_rew_mean          | -123         |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 20           |
# |    time_elapsed         | 10048        |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0036775586 |
# |    clip_fraction        | 0.2          |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.232        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 6.88e+03     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000944    |
# |    value_loss           | 1.07e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 54.5         |
# |    ep_rew_mean          | -144         |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 21           |
# |    time_elapsed         | 10558        |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0037500658 |
# |    clip_fraction        | 0.193        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.231        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 5.79e+03     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00166     |
# |    value_loss           | 1.2e+04      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 52.1         |
# |    ep_rew_mean          | -146         |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 22           |
# |    time_elapsed         | 11076        |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0031855113 |
# |    clip_fraction        | 0.199        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.241        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 3.65e+03     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00159     |
# |    value_loss           | 1.14e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.1        |
# |    ep_rew_mean          | -127        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 23          |
# |    time_elapsed         | 11595       |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.004607565 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.226       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 5.73e+03    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.000666   |
# |    value_loss           | 1.27e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.9        |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 24          |
# |    time_elapsed         | 12104       |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.004009036 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.239       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 5.34e+03    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00119    |
# |    value_loss           | 1.3e+04     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 44.6         |
# |    ep_rew_mean          | -107         |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 25           |
# |    time_elapsed         | 12635        |
# |    total_timesteps      | 204800       |
# | train/                  |              |
# |    approx_kl            | 0.0033319672 |
# |    clip_fraction        | 0.168        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.232        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 7.69e+03     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00133     |
# |    value_loss           | 1.41e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 45.2         |
# |    ep_rew_mean          | -60.1        |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 26           |
# |    time_elapsed         | 13147        |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 0.0034827697 |
# |    clip_fraction        | 0.157        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.217        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 7.21e+03     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00082     |
# |    value_loss           | 1.46e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.7        |
# |    ep_rew_mean          | -49.5       |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 27          |
# |    time_elapsed         | 13675       |
# |    total_timesteps      | 221184      |
# | train/                  |             |
# |    approx_kl            | 0.004446457 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.965      |
# |    explained_variance   | 0.245       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 8.06e+03    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.000917   |
# |    value_loss           | 1.33e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 44.9         |
# |    ep_rew_mean          | 105          |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 28           |
# |    time_elapsed         | 14193        |
# |    total_timesteps      | 229376       |
# | train/                  |              |
# |    approx_kl            | 0.0037243143 |
# |    clip_fraction        | 0.124        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.867       |
# |    explained_variance   | 0.255        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 6.26e+03     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.000395    |
# |    value_loss           | 1.52e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.8        |
# |    ep_rew_mean          | 46.3        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 29          |
# |    time_elapsed         | 14711       |
# |    total_timesteps      | 237568      |
# | train/                  |             |
# |    approx_kl            | 0.003095775 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.745      |
# |    explained_variance   | 0.256       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 6.57e+03    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00113    |
# |    value_loss           | 1.51e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 43.9         |
# |    ep_rew_mean          | 148          |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 30           |
# |    time_elapsed         | 15230        |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0041288305 |
# |    clip_fraction        | 0.109        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.691       |
# |    explained_variance   | 0.276        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 4.67e+03     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | 0.000396     |
# |    value_loss           | 1.34e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 42.6         |
# |    ep_rew_mean          | 163          |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 31           |
# |    time_elapsed         | 15752        |
# |    total_timesteps      | 253952       |
# | train/                  |              |
# |    approx_kl            | 0.0049901535 |
# |    clip_fraction        | 0.104        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.632       |
# |    explained_variance   | 0.254        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 6.01e+03     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000597    |
# |    value_loss           | 1.41e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.6        |
# |    ep_rew_mean          | 373         |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 32          |
# |    time_elapsed         | 16272       |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.004442419 |
# |    clip_fraction        | 0.0945      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.547      |
# |    explained_variance   | 0.268       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 7.85e+03    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00044    |
# |    value_loss           | 1.53e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 43.3         |
# |    ep_rew_mean          | 338          |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 33           |
# |    time_elapsed         | 16804        |
# |    total_timesteps      | 270336       |
# | train/                  |              |
# |    approx_kl            | 0.0032019066 |
# |    clip_fraction        | 0.081        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.498       |
# |    explained_variance   | 0.182        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 3.9e+03      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000233    |
# |    value_loss           | 1.98e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 41.8         |
# |    ep_rew_mean          | 372          |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 34           |
# |    time_elapsed         | 17321        |
# |    total_timesteps      | 278528       |
# | train/                  |              |
# |    approx_kl            | 0.0033290163 |
# |    clip_fraction        | 0.0697       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.416       |
# |    explained_variance   | 0.197        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 7.96e+03     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000852    |
# |    value_loss           | 1.63e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 42.4         |
# |    ep_rew_mean          | 444          |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 35           |
# |    time_elapsed         | 17835        |
# |    total_timesteps      | 286720       |
# | train/                  |              |
# |    approx_kl            | 0.0020574725 |
# |    clip_fraction        | 0.0535       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.353       |
# |    explained_variance   | 0.202        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 4.74e+03     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.000843    |
# |    value_loss           | 1.77e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 43.3         |
# |    ep_rew_mean          | 424          |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 36           |
# |    time_elapsed         | 18347        |
# |    total_timesteps      | 294912       |
# | train/                  |              |
# |    approx_kl            | 0.0019554854 |
# |    clip_fraction        | 0.0501       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.314       |
# |    explained_variance   | 0.174        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 1.54e+04     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | 0.0005       |
# |    value_loss           | 2.33e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 42.9         |
# |    ep_rew_mean          | 473          |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 37           |
# |    time_elapsed         | 18853        |
# |    total_timesteps      | 303104       |
# | train/                  |              |
# |    approx_kl            | 0.0016306757 |
# |    clip_fraction        | 0.0476       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.299       |
# |    explained_variance   | 0.206        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 4.9e+03      |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.000154    |
# |    value_loss           | 1.56e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 42.8         |
# |    ep_rew_mean          | 530          |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 38           |
# |    time_elapsed         | 19373        |
# |    total_timesteps      | 311296       |
# | train/                  |              |
# |    approx_kl            | 0.0013815328 |
# |    clip_fraction        | 0.0424       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.27        |
# |    explained_variance   | 0.174        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 4.88e+03     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | 0.000283     |
# |    value_loss           | 1.93e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.9        |
# |    ep_rew_mean          | 582         |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 39          |
# |    time_elapsed         | 19893       |
# |    total_timesteps      | 319488      |
# | train/                  |             |
# |    approx_kl            | 0.001495768 |
# |    clip_fraction        | 0.0364      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.223      |
# |    explained_variance   | 0.146       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 4.1e+03     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.000639   |
# |    value_loss           | 1.76e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 42           |
# |    ep_rew_mean          | 640          |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 40           |
# |    time_elapsed         | 20403        |
# |    total_timesteps      | 327680       |
# | train/                  |              |
# |    approx_kl            | 0.0016003489 |
# |    clip_fraction        | 0.0295       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.17        |
# |    explained_variance   | 0.166        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 5.93e+03     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00042     |
# |    value_loss           | 1.82e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 42.2         |
# |    ep_rew_mean          | 698          |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 41           |
# |    time_elapsed         | 20929        |
# |    total_timesteps      | 335872       |
# | train/                  |              |
# |    approx_kl            | 0.0014464338 |
# |    clip_fraction        | 0.0294       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.157       |
# |    explained_variance   | 0.123        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 6.36e+03     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | 0.00039      |
# |    value_loss           | 2.13e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 42           |
# |    ep_rew_mean          | 781          |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 42           |
# |    time_elapsed         | 21444        |
# |    total_timesteps      | 344064       |
# | train/                  |              |
# |    approx_kl            | 0.0024183823 |
# |    clip_fraction        | 0.0184       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.0903      |
# |    explained_variance   | 0.175        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 7.48e+03     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | 0.000809     |
# |    value_loss           | 1.61e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 42           |
# |    ep_rew_mean          | 708          |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 43           |
# |    time_elapsed         | 21960        |
# |    total_timesteps      | 352256       |
# | train/                  |              |
# |    approx_kl            | 0.0008089027 |
# |    clip_fraction        | 0.0114       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.0952      |
# |    explained_variance   | 0.143        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 1.09e+04     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | 0.000134     |
# |    value_loss           | 1.78e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 41.2         |
# |    ep_rew_mean          | 654          |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 44           |
# |    time_elapsed         | 22466        |
# |    total_timesteps      | 360448       |
# | train/                  |              |
# |    approx_kl            | 0.0011950019 |
# |    clip_fraction        | 0.0112       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.075       |
# |    explained_variance   | 0.183        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 5.22e+03     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | 6.35e-05     |
# |    value_loss           | 1.5e+04      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 42           |
# |    ep_rew_mean          | 835          |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 45           |
# |    time_elapsed         | 22972        |
# |    total_timesteps      | 368640       |
# | train/                  |              |
# |    approx_kl            | 0.0022142343 |
# |    clip_fraction        | 0.015        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.0629      |
# |    explained_variance   | 0.243        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 3.83e+03     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | 0.000422     |
# |    value_loss           | 1.49e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 41.8         |
# |    ep_rew_mean          | 809          |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 46           |
# |    time_elapsed         | 23497        |
# |    total_timesteps      | 376832       |
# | train/                  |              |
# |    approx_kl            | 0.0009430436 |
# |    clip_fraction        | 0.00869      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.0624      |
# |    explained_variance   | 0.184        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 7.15e+03     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | 0.00104      |
# |    value_loss           | 1.58e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 42           |
# |    ep_rew_mean          | 783          |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 47           |
# |    time_elapsed         | 24028        |
# |    total_timesteps      | 385024       |
# | train/                  |              |
# |    approx_kl            | 0.0007470192 |
# |    clip_fraction        | 0.00924      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.0532      |
# |    explained_variance   | 0.209        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 9.95e+03     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | 0.000176     |
# |    value_loss           | 1.58e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 41.9         |
# |    ep_rew_mean          | 808          |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 48           |
# |    time_elapsed         | 24533        |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0004548637 |
# |    clip_fraction        | 0.00747      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.0468      |
# |    explained_variance   | 0.245        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 9.16e+03     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | 2.54e-05     |
# |    value_loss           | 1.4e+04      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 41.7          |
# |    ep_rew_mean          | 744           |
# | time/                   |               |
# |    fps                  | 16            |
# |    iterations           | 49            |
# |    time_elapsed         | 25049         |
# |    total_timesteps      | 401408        |
# | train/                  |               |
# |    approx_kl            | 0.00073873723 |
# |    clip_fraction        | 0.0112        |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -0.0584       |
# |    explained_variance   | 0.247         |
# |    learning_rate        | 1e-05         |
# |    loss                 | 2.04e+04      |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -0.000374     |
# |    value_loss           | 1.49e+04      |
# -------------------------------------------

# %% [markdown]
# # 6 Level up and retrain

# %%
model.load('./train/train_deadly_corridor/best_model_340000.zip')

# %%
env = VizDoomEnv(config='ViZDoom/gtihub/ViZDoom/scenarios/deadly_corridor_s2.cfg')
model.set_env(env)
model.learn(total_timesteps=40000, callback=callback)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# Logging to ./logs/log_deadly_corridor\PPO_3
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.6     |
# |    ep_rew_mean     | -89.8    |
# | time/              |          |
# |    fps             | 26       |
# |    iterations      | 1        |
# |    time_elapsed    | 305      |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 31.2        |
# |    ep_rew_mean          | -83.9       |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 2           |
# |    time_elapsed         | 833         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.004194458 |
# |    clip_fraction        | 0.00747     |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.0288     |
# |    explained_variance   | 0.189       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 2.07e+04    |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.00237     |
# |    value_loss           | 2.37e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30.6         |
# |    ep_rew_mean          | -142         |
# | time/                   |              |
# |    fps                  | 18           |
# |    iterations           | 3            |
# |    time_elapsed         | 1341         |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0026057062 |
# |    clip_fraction        | 0.00809      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.0291      |
# |    explained_variance   | 0.361        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 9.61e+03     |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.000823    |
# |    value_loss           | 1.91e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.9         |
# |    ep_rew_mean          | -10          |
# | time/                   |              |
# |    fps                  | 17           |
# |    iterations           | 4            |
# |    time_elapsed         | 1878         |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0002611685 |
# |    clip_fraction        | 0.00463      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.0284      |
# |    explained_variance   | 0.439        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 5.98e+03     |
# |    n_updates            | 520          |
# |    policy_gradient_loss | 0.000371     |
# |    value_loss           | 1.65e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.3        |
# |    ep_rew_mean          | -38.8       |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 5           |
# |    time_elapsed         | 2443        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.000730103 |
# |    clip_fraction        | 0.005       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.0232     |
# |    explained_variance   | 0.404       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 1.3e+04     |
# |    n_updates            | 530         |
# |    policy_gradient_loss | 0.000585    |
# |    value_loss           | 1.86e+04    |
# -----------------------------------------

# %%
# reload model from disk
model = PPO.load('./train/train_basic/best_model_170000')

# %%
env = VizDoomEnv(render = True)

# %%
# evaluate mean reward for 10 games
mean_reward, _ = evaluate_policy(model, env, n_eval_episodes = 10)

# %%
mean_reward
